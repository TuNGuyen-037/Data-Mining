# %%
import pandas as pd

# %%
UserID Age Car Risk
1 25 Sports L
2 20 Vintage H
3 25 Sports L
4 45 SUV H
5 20 Sports H
6 25 SUV H

# %%
data = {
    "Mã SV": ["SV01", "SV02", "SV03", "SV04", "SV05", "SV06", "SV07", "SV08", "SV09", "SV10", "SV11", "SV12", "SV13", "SV14", "SV15", "SV16", "SV17", "SV18", "SV19", "SV20", "SV21", "SV22", "SV23"],
    "Kiến trúc máy tính": [7.8, 8.8, 8.1, 6.1, 8.8, 5.3, 7.6, 8.3, 8.8, 8.6, 8.1, 7.6, 7.6, 6.3, 8.1, 6.8, 0.3, 8.6, 6.3, 8.1, 7.8, 8.3, 4.8],
    "Lập trình Python cơ bản": [9.1, 9.3, 8.5, 6.5, 9.1, 6.3, 9.6, 7.3, 8.1, 9.1, 7.6, 8.2, 7.8, 7.1, 8.1, 7.0, 8.7, 9.2, 7.5, 7.6, 8.4, 8.2, 5.6],
    "Cấu trúc dữ liệu và giải thuật": [8.2, 9.2, 7.2, 6.7, 9.1, 6.5, 9.0, 7.0, 8.7, 8.8, 6.7, 7.0, 7.6, 7.1, 7.4, 7.0, 9.2, 7.2, 6.3, 7.2, 7.7, 8.2, 6.2],
    "Cơ sở kỹ thuật lập trình": [7.7, 9.4, 7.4, 5.6, 8.5, 6.6, 8.5, 6.6, 8.6, 8.8, 8.3, 6.3, 6.3, 6.9, 8.1, 6.8, 7.2, 7.7, 6.5, 7.6, 6.9, 6.6, 7.5],
    "Hệ điều hành": [7.0, 8.0, 7.3, 6.6, 7.3, 6.6, 6.1, 5.8, 8.6, 8.6, 6.1, 5.9, 6.3, 6.8, 6.5, 6.7, 7.8, 7.6, 6.5, 7.2, 6.7, 6.8, 5.6],
    "Cơ sở dữ liệu": [6.7, 8.1, 6.6, 6.6, 8.1, 6.6, 6.7, 6.6, 8.2, 8.6, 6.9, 6.0, 6.3, 6.3, 7.1, 7.1, 7.2, 7.7, 6.8, 6.2, 7.8, 6.6, 7.5],
    "Lập trình hướng đối tượng": [8.1, 8.8, 6.5, 6.6, 7.8, 6.6, 6.7, 6.6, 8.6, 8.2, 8.3, 4.8, 4.6, 5.3, 8.1, 7.3, 7.7, 7.7, 5.3, 7.6, 6.7, 7.2, 6.7],
    "Lập trình ứng dụng Window & Form": [7.3, 7.3, 2.8, 6.6, 8.3, 6.2, 6.8, 7.3, 6.1, 6.8, 7.1, 5.3, 5.3, 5.8, 6.6, 6.3, 7.8, 7.0, 6.6, 7.6, 6.4, 6.8, 7.2],
    "Mạng máy tính": [7.4, 8.3, 5.8, 7.0, 8.1, 6.8, 8.0, 7.7, 7.9, 7.1, 8.4, 6.6, 7.6, 7.6, 7.3, 6.8, 8.3, 7.7, 7.6, 8.4, 7.4, 8.0, 7.0],
    "Công nghệ phần mềm": [7.8, 8.3, 6.2, 6.3, 8.1, 6.8, 8.1, 0.3, 8.2, 7.9, 7.7, 5.8, 6.5, 7.6, 5.4, 5.3, 7.7, 6.8, 8.0, 8.2, 6.8, 7.3, 6.8],
    "Hệ quản trị cơ sở dữ liệu 1": [7.6, 8.2, 7.2, 5.6, 8.1, 5.2, 8.4, 6.1, 8.8, 9.1, 8.0, 8.6, 8.5, 8.0, 8.4, 8.1, 9.4, 8.6, 8.1, 8.2, 7.8, 8.0, 7.5],
    "Lập trình Python nâng cao": [9.6, 9.6, 8.5, 8.3, 9.1, 5.6, 9.1, 7.6, 9.3, 9.1, 8.3, 7.8, 8.1, 8.1, 8.4, 8.5, 9.6, 8.6, 8.5, 8.6, 8.0, 8.3, 5.3],
    "Toán rời rạc": [7.6, 7.6, 5.8, 5.8, 6.3, 5.3, 6.8, 5.6, 9.3, 9.1, 6.8, 6.8, 5.8, 7.6, 5.4, 5.8, 7.2, 7.6, 6.6, 7.2, 6.8, 6.3, 5.6]
}

df = pd.DataFrame(data)
print(df)
# Out:
#    Mã SV  Kiến trúc máy tính  Lập trình Python cơ bản  \
# 0   SV01                 7.8                      9.1
# 1   SV02                 8.8                      9.3
# 2   SV03                 8.1                      8.5
# 3   SV04                 6.1                      6.5
# 4   SV05                 8.8                      9.1
# 5   SV06                 5.3                      6.3
# 6   SV07                 7.6                      9.6
# 7   SV08                 8.3                      7.3
# 8   SV09                 8.8                      8.1
# 9   SV10                 8.6                      9.1
# 10  SV11                 8.1                      7.6
# 11  SV12                 7.6                      8.2
# 12  SV13                 7.6                      7.8
# 13  SV14                 6.3                      7.1
# 14  SV15                 8.1                      8.1
# 15  SV16                 6.8                      7.0
# ...

# %%
df.shape
# Out:
# (23, 14)
